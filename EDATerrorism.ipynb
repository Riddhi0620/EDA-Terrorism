# %% [markdown]
# ![EDA on Terrorism.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("gtd.csv", encoding="latin1")
df=pd.DataFrame(data)
print("Data has been successfully imported")
df.head()
# Out:
# Data has been successfully imported
#    Unnamed: 0  Year  Month  Day             Country  \
# 0           0  1970      7    2  Dominican Republic
# 1           1  1970      0    0              Mexico
# 2           2  1970      1    0         Philippines
# 3           3  1970      1    0              Greece
# 4           4  1970      1    0               Japan
#
#                         Region  Province  Success  \
# 0  Central America & Caribbean  National      1.0
# 1                North America   Federal      1.0
# 2               Southeast Asia    Tarlac      1.0
# 3               Western Europe    Attica      1.0
# 4                    East Asia   Fukouka      1.0
#
#                        AttackType                       Target  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                      Sub_Target_Type Weapon_type    Killed  \
# 0                                     Named Civilian     Unknown  1.000000
# 1  Diplomatic Personnel (outside of embassy, cons...     Unknown  0.000000
# 2                    Radio Journalist/Staff/Facility     Unknown  1.000000
# 3                                  Embassy/Consulate  Explosives  2.415802
# 4                                  Embassy/Consulate  Incendiary  2.415802
#
#     Wounded                               Group  Total_Casualities
# 0  0.000000                              MANO-D           1.000000
# 1  0.000000  23rd of September Communist League           0.000000
# 2  0.000000                             Unknown           1.000000
# 3  3.144579                             Unknown           5.560381
# 4  3.144579                             Unknown           5.560381

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48084 entries, 0 to 48083
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         48084 non-null  int64
#  1   Year               48084 non-null  int64
#  2   Month              48084 non-null  int64
#  3   Day                48084 non-null  int64
#  4   Country            48084 non-null  object
#  5   Region             48084 non-null  object
#  6   Province           48084 non-null  object
#  7   Success            48084 non-null  float64
#  8   AttackType         48084 non-null  object
#  9   Target             48084 non-null  object
#  10  Sub_Target_Type    48084 non-null  object
#  11  Weapon_type        48084 non-null  object
#  12  Killed             48084 non-null  float64
#  13  Wounded            48084 non-null  float64
#  14  Group              48084 non-null  object
#  15  Total_Casualities  48083 non-null  float64
# dtypes: float64(4), int64(4), object(8)
# memory usage: 5.9+ MB

# %%
df.shape
# Out:
# (48084, 16)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'Day', 'Country', 'Region', 'Province',
#        'Success', 'AttackType', 'Target', 'Sub_Target_Type', 'Weapon_type',
#        'Killed', 'Wounded', 'Group', 'Total_Casualities'],
#       dtype='object')

# %%
for i in df.columns:
    print(i,end=", ")
# Out:
# Unnamed: 0, Year, Month, Day, Country, Region, Province, Success, AttackType, Target, Sub_Target_Type, Weapon_type, Killed, Wounded, Group, Total_Casualities,

# %%
df.head()
# Out:
#    Unnamed: 0  Year  Month  Day             Country  \
# 0           0  1970      7    2  Dominican Republic
# 1           1  1970      0    0              Mexico
# 2           2  1970      1    0         Philippines
# 3           3  1970      1    0              Greece
# 4           4  1970      1    0               Japan
#
#                         Region  Province  Success  \
# 0  Central America & Caribbean  National      1.0
# 1                North America   Federal      1.0
# 2               Southeast Asia    Tarlac      1.0
# 3               Western Europe    Attica      1.0
# 4                    East Asia   Fukouka      1.0
#
#                        AttackType                       Target  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                      Sub_Target_Type Weapon_type    Killed  \
# 0                                     Named Civilian     Unknown  1.000000
# 1  Diplomatic Personnel (outside of embassy, cons...     Unknown  0.000000
# 2                    Radio Journalist/Staff/Facility     Unknown  1.000000
# 3                                  Embassy/Consulate  Explosives  2.415802
# 4                                  Embassy/Consulate  Incendiary  2.415802
#
#     Wounded                               Group  Total_Casualities
# 0  0.000000                              MANO-D           1.000000
# 1  0.000000  23rd of September Communist League           0.000000
# 2  0.000000                             Unknown           1.000000
# 3  3.144579                             Unknown           5.560381
# 4  3.144579                             Unknown           5.560381

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48084 entries, 0 to 48083
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         48084 non-null  int64
#  1   Year               48084 non-null  int64
#  2   Month              48084 non-null  int64
#  3   Day                48084 non-null  int64
#  4   Country            48084 non-null  object
#  5   Region             48084 non-null  object
#  6   Province           48084 non-null  object
#  7   Success            48084 non-null  float64
#  8   AttackType         48084 non-null  object
#  9   Target             48084 non-null  object
#  10  Sub_Target_Type    48084 non-null  object
#  11  Weapon_type        48084 non-null  object
#  12  Killed             48084 non-null  float64
#  13  Wounded            48084 non-null  float64
#  14  Group              48084 non-null  object
#  15  Total_Casualities  48083 non-null  float64
# dtypes: float64(4), int64(4), object(8)
# memory usage: 5.9+ MB

# %%
df.shape
# Out:
# (48084, 16)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Year                 0
# Month                0
# Day                  0
# Country              0
# Region               0
# Province             0
# Success              0
# AttackType           0
# Target               0
# Sub_Target_Type      0
# Weapon_type          0
# Killed               0
# Wounded              0
# Group                0
# Total_Casualities    1
# dtype: int64

# %%
df["Killed"]=df["Killed"].fillna(0)
df["Wounded"]=df["Wounded"].fillna(0)
df["Casualty"]=df["Killed"]+df["Wounded"]

# %%
df.describe()
# Out:
#          Unnamed: 0          Year         Month           Day       Success  \
# count  48084.000000  48084.000000  48084.000000  48084.000000  48084.000000
# mean   24041.500000   1983.890359      6.316384     15.316009      0.920576
# std    13880.799509      5.182749      3.348219      8.843270      0.270401
# min        0.000000   1970.000000      0.000000      0.000000      0.000000
# 25%    12020.750000   1980.000000      3.000000      8.000000      1.000000
# 50%    24041.500000   1984.000000      6.000000     15.000000      1.000000
# 75%    36062.250000   1988.000000      9.000000     23.000000      1.000000
# max    48083.000000   1991.000000     12.000000     31.000000      1.000000
#
#              Killed       Wounded  Total_Casualities      Casualty
# count  48084.000000  48084.000000       48083.000000  48084.000000
# mean       2.114915      1.908635           4.023634      4.023550
# std        8.008658      9.247855          13.423395     13.423268
# min        0.000000      0.000000           0.000000      0.000000
# 25%        0.000000      0.000000           0.000000      0.000000
# 50%        0.000000      0.000000           1.000000      1.000000
# 75%        2.415802      2.000000           5.000000      5.000000
# max      422.000000    751.000000         760.000000    760.000000

# %% [markdown]
# **Years**

# %%
attacks=df["Year"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"Year","Year":"Attacks"}).set_index("Year")
attacks.head()
# Out:
#       Attacks
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581

# %%
attacks.plot(kind="bar",color="cornflowerblue",figsize=(15,6),fontsize=13)
plt.title("Timeline of Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %%
yc=df[["Year","Casualty"]].groupby("Year").sum()
yc.head()
# Out:
#          Casualty
# Year
# 1970   650.981769
# 1971   865.575225
# 1972  2109.572505
# 1973  1703.482805
# 1974  2264.225022

# %%
yc.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Year wise Casualties",fontsize=13)
plt.xlabel("Years",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %%
yk=df[["Year","Killed"]].groupby("Year").sum()
yk.head()
# Out:
#           Killed
# Year
# 1970  275.463678
# 1971  327.611319
# 1972  672.295282
# 1973  488.374291
# 1974  679.116508

# %%
yw=df[["Year","Wounded"]].groupby("Year").sum()
yw.head()
# Out:
#           Wounded
# Year
# 1970   375.518091
# 1971   537.963906
# 1972  1437.277223
# 1973  1215.108514
# 1974  1585.108514

# %%
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)


yk.plot(kind="bar",color="red",figsize=(15,15),ax=ax0)
ax0.set_title("People Killed in each Year")
ax0.set_xlabel("Years")
ax0.set_ylabel("Number of People Killed")


yw.plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax1)
ax1.set_title("People Wounded in each Year")
ax1.set_xlabel("Years")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %%
reg=pd.crosstab(df.Year,df.Region)
reg.head()
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 1970            2              12                          28            472
# 1971            1               5                          55            247
# 1972            0               1                          53             73
# 1973            2               1                          19             64
# 1974            4               2                          42            111
#
# Region  South America  South Asia  Southeast Asia  Sub-Saharan Africa  \
# Year
# 1970               65           1              10                   3
# 1971               24           0               6                   2
# 1972               33           1              16                   4
# 1973               83           1               2                   4
# 1974               81           2               3                   7
#
# Region  Western Europe
# Year
# 1970                50
# 1971               125
# 1972               376
# 1973               290
# 1974               317

# %%
reg.plot(kind="area", stacked=False, alpha=0.5,figsize=(20,10))
plt.title("Region wise attacks",fontsize=20)
plt.xlabel("Years",fontsize=20)
plt.ylabel("Number of Attacks",fontsize=20)
plt.show()

# %%
regt=reg.transpose()
regt["Total"]=regt.sum(axis=1)
ra=regt["Total"].sort_values(ascending=False)
ra
# Out:
# Region
# South America                  12685
# Western Europe                 10307
# Central America & Caribbean     9216
# Middle East & North Africa      4867
# South Asia                      3969
# Sub-Saharan Africa              2412
# North America                   2223
# Southeast Asia                  1776
# East Asia                        307
# Eastern Europe                   200
# Australasia & Oceania            119
# Central Asia                       3
# Name: Total, dtype: int64

# %% [markdown]
# **Region**

# %%
ra.plot(kind="bar",figsize=(15,6))
plt.title("Total Number of Attacks in each Region from 1970-2017")
plt.xlabel("Region")
plt.ylabel("Number of Attacks")
plt.show()

# %%
rc=df[["Region","Casualty"]].groupby("Region").sum().sort_values(by="Casualty",ascending=False)
rc
# Out:
#                                  Casualty
# Region
# Central America & Caribbean  48925.046720
# South America                35642.738913
# South Asia                   29072.258294
# Middle East & North Africa   25638.230851
# Western Europe               24310.973440
# Sub-Saharan Africa           14512.417972
# Southeast Asia               10974.759273
# North America                 2907.222993
# Eastern Europe                 701.821510
# East Asia                      578.227218
# Australasia & Oceania          194.681142
# Central Asia                    10.000000

# %%
rc.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Region wise Casualties",fontsize=13)
plt.xlabel("Regions",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %%
rk=df[["Region","Killed"]].groupby("Region").sum().sort_values(by="Killed",ascending=False)
rk
# Out:
#                                    Killed
# Region
# Central America & Caribbean  33402.660311
# South America                23089.919060
# South Asia                   14554.679951
# Middle East & North Africa    9055.086068
# Sub-Saharan Africa            7544.707071
# Western Europe                7267.984645
# Southeast Asia                5256.590564
# North America                  910.174762
# Eastern Europe                 377.652830
# East Asia                      153.889858
# Australasia & Oceania           78.247406
# Central Asia                     2.000000

# %%
rw=df[["Region","Wounded"]].groupby("Region").sum().sort_values(by="Wounded",ascending=False)
rw
# Out:
#                                   Wounded
# Region
# Western Europe               17042.988796
# Middle East & North Africa   16583.144783
# Central America & Caribbean  15522.386409
# South Asia                   14517.578344
# South America                12552.819853
# Sub-Saharan Africa            6967.710901
# Southeast Asia                5718.168709
# North America                 1997.048232
# East Asia                      424.337360
# Eastern Europe                 324.168680
# Australasia & Oceania          116.433736
# Central Asia                     8.000000

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)


rk.plot(kind="bar",color="red",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Region")
ax0.set_xlabel("Regions")
ax0.set_ylabel("Number of People Killed")


rw.plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Region")
ax1.set_xlabel("Regions")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# **Country**

# %%
coun=df["Country"].value_counts()[1:11]
coun
# Out:
# El Salvador       5103
# Colombia          4045
# United Kingdom    3231
# Spain             2426
# Chile             2060
# United States     2050
# India             1840
# Nicaragua         1827
# Guatemala         1743
# Sri Lanka         1553
# Name: Country, dtype: int64

# %%
coun.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Country wise Attacks",fontsize=13)
plt.xlabel("Countrise",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %%
cc=df[["Country","Casualty"]].groupby("Country").sum().sort_values(by="Casualty",ascending=False)
cc.head(10)
# Out:
#                     Casualty
# Country
# El Salvador     24317.379492
# Peru            17421.245129
# Nicaragua       15396.365663
# Colombia        12944.468870
# Sri Lanka       12853.769948
# United Kingdom  11643.083094
# Lebanon         11242.379566
# India            9925.033331
# Philippines      8492.769367
# Guatemala        7956.569740

# %%
cc[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Country wise Casualties",fontsize=13)
plt.xlabel("Countrise",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Countrise",fontsize=13)
plt.show()

# %%
ck=df[["Country","Killed"]].groupby("Country").sum().sort_values(by="Killed",ascending=False)
ck.head(10)
# Out:
#                       Killed
# Country
# El Salvador     15236.222366
# Peru            12464.618378
# Nicaragua       11809.859418
# Colombia         8348.541028
# Sri Lanka        8193.553065
# Guatemala        5797.967208
# India            4777.563443
# Philippines      4197.769338
# Lebanon          3400.933721
# United Kingdom   3355.528297

# %%
cw=df[["Country","Wounded"]].groupby("Country").sum().sort_values(by="Wounded",ascending=False)
cw.head(10)
# Out:
#                     Wounded
# Country
# El Salvador     9081.157125
# United Kingdom  8287.554797
# Lebanon         7841.445845
# India           5147.469888
# Peru            4956.626751
# Sri Lanka       4660.216883
# Colombia        4595.927842
# Philippines     4295.000029
# Nicaragua       3586.506244
# South Africa    3176.843400

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)


ck[:10].plot(kind="bar",color="red",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Country")
ax0.set_xlabel("Countrise")
ax0.set_ylabel("Number of People Killed")


cw[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Country")
ax1.set_xlabel("Countrise")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# **Attack Type**

# %%
at=df["AttackType"].value_counts()
at
# Out:
# Bombing/Explosion                      21594
# Armed Assault                          10831
# Assassination                           8523
# Facility/Infrastructure Attack          3044
# Hostage Taking (Kidnapping)             1967
# Unknown                                 1314
# Hostage Taking (Barricade Incident)      532
# Hijacking                                196
# Unarmed Assault                           83
# Name: AttackType, dtype: int64

# %%
at.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Types of Attacks",fontsize=13)
plt.xlabel("Attack Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %%
ac=df[["AttackType","Casualty"]].groupby("AttackType").sum().sort_values(by="Casualty",ascending=False)
ac
# Out:
#                                          Casualty
# AttackType
# Bombing/Explosion                    81360.522257
# Armed Assault                        75309.718799
# Assassination                        17058.187773
# Unknown                               7288.228807
# Facility/Infrastructure Attack        4483.414714
# Hostage Taking (Kidnapping)           4267.462917
# Hostage Taking (Barricade Incident)   1530.197219
# Unarmed Assault                       1364.566548
# Hijacking                              806.079293

# %%
ac.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Casualties in each Attack",fontsize=13)
plt.xlabel("Attack Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %%
ak=df[["AttackType","Killed"]].groupby("AttackType").sum().sort_values(by="Killed",ascending=False)
ak
# Out:
#                                            Killed
# AttackType
# Armed Assault                        54023.440992
# Bombing/Explosion                    25559.677748
# Assassination                        10980.958489
# Unknown                               5108.397400
# Hostage Taking (Kidnapping)           2498.595270
# Facility/Infrastructure Attack        2293.595270
# Hostage Taking (Barricade Incident)    688.185139
# Hijacking                              443.910613
# Unarmed Assault                         96.831604

# %%
aw=df[["AttackType","Wounded"]].groupby("AttackType").sum().sort_values(by="Wounded",ascending=False)
aw
# Out:
#                                           Wounded
# AttackType
# Bombing/Explosion                    55800.844509
# Armed Assault                        21286.277807
# Assassination                         6077.229283
# Facility/Infrastructure Attack        2189.819444
# Unknown                               2179.831408
# Hostage Taking (Kidnapping)           1768.867647
# Unarmed Assault                       1267.734944
# Hostage Taking (Barricade Incident)    842.012080
# Hijacking                              362.168680

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)


ak.plot(kind="bar",color="red",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Attack Type")
ax0.set_xlabel("Attack Types")
ax0.set_ylabel("Number of people Killed")


aw.plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Attack Type")
ax1.set_xlabel("Attack Types")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
# **Target**

# %%
ta=df["Target"].value_counts()
ta
# Out:
# Business                          8414
# Private Citizens & Property       7862
# Military                          7471
# Government (General)              6134
# Police                            5271
# Utilities                         3111
# Transportation                    2365
# Government (Diplomatic)           1705
# Journalists & Media               1085
# Educational Institution            978
# Airports & Aircraft                782
# Religious Figures/Institutions     748
# Terrorists/Non-State Militia       455
# Violent Political Party            366
# Telecommunication                  348
# Unknown                            312
# NGO                                152
# Food or Water Supply               135
# Maritime                           130
# Tourists                           126
# Abortion Related                   121
# Other                               13
# Name: Target, dtype: int64

# %%
ta.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Types of Targets",fontsize=13)
plt.xlabel("Target",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %%
tc=df[["Target","Casualty"]].groupby("Target").sum().sort_values(by="Casualty",ascending=False)
tc
# Out:
#                                     Casualty
# Target
# Military                        52721.361348
# Private Citizens & Property     43285.964486
# Business                        23414.594814
# Police                          19119.225961
# Government (General)            14104.646129
# Transportation                  14095.097315
# Airports & Aircraft              4965.175075
# Utilities                        4394.362799
# Religious Figures/Institutions   3581.906105
# Government (Diplomatic)          2351.964346
# Terrorists/Non-State Militia     2265.874519
# Educational Institution          2209.796530
# Violent Political Party          1530.506862
# Journalists & Media              1495.505119
# Unknown                          1172.603224
# Maritime                         1041.076755
# Telecommunication                 664.298089
# Food or Water Supply              373.197516
# Tourists                          341.134485
# NGO                               292.429525
# Abortion Related                   28.096943
# Other                              19.560381

# %%
tc.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Casualties in each Target Attack",fontsize=13)
plt.xlabel("Target",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %%
tk=df[["Target","Killed"]].groupby("Target").sum().sort_values(by="Killed",ascending=False)
tk
# Out:
#                                       Killed
# Target
# Military                        36210.818601
# Private Citizens & Property     24226.084409
# Police                           9849.478762
# Business                         7965.714824
# Government (General)             6000.959183
# Transportation                   5174.362254
# Airports & Aircraft              2534.006365
# Utilities                        2072.302341
# Religious Figures/Institutions   1174.363913
# Terrorists/Non-State Militia     1158.910613
# Unknown                           866.374291
# Government (Diplomatic)           842.301647
# Educational Institution           774.916978
# Violent Political Party           762.494811
# Journalists & Media               719.143629
# Maritime                          577.305659
# Telecommunication                 252.611319
# Food or Water Supply              209.137263
# NGO                               153.405424
# Tourists                          149.821226
# Abortion Related                    9.663207
# Other                               9.415802

# %%
tw=df[["Target","Wounded"]].groupby("Target").sum().sort_values(by="Wounded",ascending=False)
tw
# Out:
#                                      Wounded
# Target
# Private Citizens & Property     19059.880077
# Military                        16510.542746
# Business                        15448.879990
# Police                           9269.747199
# Transportation                   8920.735061
# Government (General)             8103.686946
# Airports & Aircraft              2431.168709
# Religious Figures/Institutions   2407.542192
# Utilities                        2322.060458
# Government (Diplomatic)          1509.662698
# Educational Institution          1434.879552
# Terrorists/Non-State Militia     1106.963906
# Journalists & Media               776.361490
# Violent Political Party           768.012051
# Maritime                          463.771096
# Telecommunication                 411.686771
# Unknown                           306.228933
# Tourists                          191.313259
# Food or Water Supply              164.060253
# NGO                               139.024101
# Abortion Related                   18.433736
# Other                              10.144579

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)


tk.plot(kind="bar",color="red",figsize=(17,6),ax=ax0)
ax0.set_title("People Killed in each Target Attack")
ax0.set_xlabel("Target Types")
ax0.set_ylabel("Number of people Killed")


tw.plot(kind="bar",color="cornflowerblue",figsize=(17,6),ax=ax1)
ax1.set_title("People Wounded in each Target Attack")
ax1.set_xlabel("Target Types")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
# **Weapon_Type**

# %%
wt=df["Weapon_type"].value_counts()
wt
# Out:
# Explosives                                                                     21682
# Firearms                                                                       18128
# Unknown                                                                         4065
# Incendiary                                                                      3612
# Melee                                                                            463
# Chemical                                                                          59
# Sabotage Equipment                                                                29
# Other                                                                             17
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)       12
# Biological                                                                         8
# Fake Weapons                                                                       6
# Radiological                                                                       3
# Name: Weapon_type, dtype: int64

# %%
ta.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Types of Weapons",fontsize=13)
plt.xlabel("Weapon",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %%
wc=df[["Weapon_type","Casualty"]].groupby("Weapon_type").sum().sort_values(by="Casualty",ascending=False)
wc
# Out:
#                                                         Casualty
# Weapon_type
# Firearms                                            93506.608412
# Explosives                                          77537.367073
# Unknown                                             14708.039122
# Incendiary                                           4711.168982
# Melee                                                1691.664059
# Biological                                            778.000000
# Chemical                                              333.265340
# Vehicle (not to include vehicle-borne explosive...     89.144579
# Sabotage Equipment                                     85.560381
# Other                                                  27.560381
# Fake Weapons                                            0.000000
# Radiological                                            0.000000

# %%
wc.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Casualties by a Weapon",fontsize=13)
plt.xlabel("Weapon",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %%
wk=df[["Weapon_type","Killed"]].groupby("Weapon_type").sum().sort_values(by="Killed",ascending=False)
wk
# Out:
#                                                           Killed
# Weapon_type
# Firearms                                            65841.426602
# Explosives                                          23070.076807
# Unknown                                              9499.930403
# Incendiary                                           2204.337486
# Melee                                                 973.158019
# Chemical                                               32.831604
# Sabotage Equipment                                     32.415802
# Vehicle (not to include vehicle-borne explosive...     31.000000
# Other                                                   8.415802
# Biological                                              0.000000
# Fake Weapons                                            0.000000
# Radiological                                            0.000000

# %%
ww=df[["Weapon_type","Wounded"]].groupby("Weapon_type").sum().sort_values(by="Wounded",ascending=False)
ww
# Out:
#                                                          Wounded
# Weapon_type
# Explosives                                          54467.290266
# Firearms                                            27665.181811
# Unknown                                              5208.108719
# Incendiary                                           2506.831495
# Biological                                            778.000000
# Melee                                                 718.506040
# Chemical                                              300.433736
# Vehicle (not to include vehicle-borne explosive...     58.144579
# Sabotage Equipment                                     53.144579
# Other                                                  19.144579
# Fake Weapons                                            0.000000
# Radiological                                            0.000000

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)


tk.plot(kind="bar",color="red",figsize=(17,6),ax=ax0)
ax0.set_title("People Killed by a Weapon")
ax0.set_xlabel("Weapon Types")
ax0.set_ylabel("Number of people Killed")


tw.plot(kind="bar",color="cornflowerblue",figsize=(17,6),ax=ax1)
ax1.set_title("People Wounded by a Weapon")
ax1.set_xlabel("Weapon Types")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
# **Top-10**

# %%
gca=df[["Group","Country"]].value_counts().drop("Unknown")
gca.head(10)
# Out:
# <ipython-input-67-317783622712>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gca=df[["Group","Country"]].value_counts().drop("Unknown")
# Group                                             Country
# Shining Path (SL)                                 Peru              3844
# Farabundo Marti National Liberation Front (FMLN)  El Salvador       3173
# Irish Republican Army (IRA)                       United Kingdom    2078
# Basque Fatherland and Freedom (ETA)               Spain             1515
# Nicaraguan Democratic Force (FDN)                 Nicaragua          886
# New People's Army (NPA)                           Philippines        852
# Manuel Rodriguez Patriotic Front (FPMR)           Chile              798
# Revolutionary Armed Forces of Colombia (FARC)     Colombia           767
# National Liberation Army of Colombia (ELN)        Colombia           682
# African National Congress (South Africa)          South Africa       573
# dtype: int64

# %%
gca.head(10).plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Countries with most attacks by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %%
gck=df[["Group","Country","Killed"]].groupby(["Group","Country"],axis=0).sum().sort_values(by="Killed",ascending=False).drop("Unknown").head(10)
gck
# Out:
# <ipython-input-69-beb63f1ad9c9>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gck=df[["Group","Country","Killed"]].groupby(["Group","Country"],axis=0).sum().sort_values(by="Killed",ascending=False).drop("Unknown").head(10)
#                                                                        Killed
# Group                                            Country
# Shining Path (SL)                                Peru            11208.842675
# Farabundo Marti National Liberation Front (FMLN) El Salvador      9827.157053
# Nicaraguan Democratic Force (FDN)                Nicaragua        7552.836310
# Liberation Tigers of Tamil Eelam (LTTE)          Sri Lanka        4374.910613
# New People's Army (NPA)                          Philippines      2691.316037
# Revolutionary Armed Forces of Colombia (FARC)    Colombia         2379.185139
# Mozambique National Resistance Movement (MNR)    Mozambique       2188.910613
# Irish Republican Army (IRA)                      United Kingdom   1988.875468
# Democratic Revolutionary Alliance (ARDE)         Nicaragua        1902.047876
# Sikh Extremists                                  India            1834.910613

# %%
gck.plot(kind="bar",color="red",figsize=(15,6))
plt.title("Countries with most people killed by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of people Killed",fontsize=13)
plt.show()

# %% [markdown]
# **Humanity Affected**

# %%
casualty=df.loc[:,"Casualty"].sum()
print("Total number of Casualties due to Terrorist Attacks from 1970 to 2019 across the world :\n",casualty)
# Out:
# Total number of Casualties due to Terrorist Attacks from 1970 to 2019 across the world :
#  193468.37832638482

# %%
kill=df.loc[:,"Killed"].sum()
print("Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :\n",kill)
# Out:
# Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :
#  101693.59252388599

# %%
wound=df.loc[:,"Wounded"].sum()
print("Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :\n",wound)
# Out:
# Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :
#  91774.78580249882
